# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
df = mouse_metadata.merge(study_results)

# Display the data table for preview
df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
df['Mouse ID'].nunique()
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

dup_ID = df[df.duplicated(['Mouse ID', 'Timepoint'])]

dup_ID
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
df[df['Mouse ID'] == "g989"]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = df[df['Mouse ID'] != "g989"]

clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.

clean_df['Mouse ID'].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
clean_df['Tumor Volume (mm3)'].astype(int)
print(clean_df.dtypes)
# Out:
# Mouse ID               object
# Drug Regimen           object
# Sex                    object
# Age_months              int64
# Weight (g)              int64
# Timepoint               int64
# Tumor Volume (mm3)    float64
# Metastatic Sites        int64
# dtype: object

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
clean_df['Tumor Volume (mm3)']
clean_group = clean_df.groupby(['Drug Regimen'])

# mean, median, variance, standard deviation, and SEM of the tumor volume. 
vol_avg = clean_group['Tumor Volume (mm3)'].mean()
vol_med = clean_group['Tumor Volume (mm3)'].median()
vol_var = clean_group['Tumor Volume (mm3)'].var()
vol_dev = clean_group['Tumor Volume (mm3)'].std()
vol_err = clean_group['Tumor Volume (mm3)'].sem()

# Assemble the resulting series into a single summary DataFrame.
summary_df = pd.DataFrame({"Mean Tumor Volume": vol_avg,
                         "Median Tumor Volume": vol_med,
                         "Tumor Volume Variance": vol_var,
                         "Tumor Volume Std. Dev.": vol_dev,
                         "Tumor Volume Std. Err.": vol_err})

summary_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
clean_group["Tumor Volume (mm3)"].agg([ "mean", "median", "var", "std", "sem"])
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
clean_df['Drug Regimen'].value_counts().plot.bar(ylabel='# Of Observed Mouse Timepoints');

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
df2  = clean_df['Drug Regimen'].value_counts(ascending=False)
plt.bar(df2.keys(),df2)
plt.xticks(rotation=45);

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
clean_df.Sex.value_counts().plot.pie(autopct='%.2f%%',ylabel='Sex');

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
df3 = clean_df.Sex.value_counts()
plt.pie(df3, autopct='%.1f%%', labels=['Male','Female']);

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
group_df = clean_df.groupby(['Mouse ID'], as_index=False).max('Timepoint')

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint

treatment_df = group_df.merge(clean_df)
treatment_df
# Out:
#     Mouse ID  Age_months  Weight (g)  Timepoint  Tumor Volume (mm3)  \
# 0       a203          20          23         45           67.973419
# 1       a251          21          25         45           65.525743
# 2       a262          17          29         45           70.717621
# 3       a275          20          28         45           62.999356
# 4       a366          16          29         30           63.440686
# ..       ...         ...         ...        ...                 ...
# 194     z314          21          28          5           45.934712
# 195     z435          12          26         10           48.710661
# 196     z581          24          25         45           62.754451
# 197     z795          13          29         45           65.741070
# 198     z969           9          30         45           73.867845
#
#      Metastatic Sites Drug Regimen     Sex
# 0                   2    Infubinol  Female
# 1                   1    Infubinol  Female
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ceftamin', 'Infubinol', 'Ramicane']

# Create empty list to fill with tumor vol data (for plotting)
vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for treatment in treatments:

    quartiles = vol_data.quartile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq

    # Locate the rows which contain mice on each drug and get the tumor volumes

    
    # add subset 

    
    # Determine outliers using upper and lower bounds
    upper_bound = upperq + (1.5*iqr)
    lower_bound = lowerq - (1.5*iqr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/aaronwalker/Desktop/DataVisualization-Challenge/Pymaceuticals/pymaceuticals_solution.ipynb Cell 19 line 2
#       <a href='vscode-notebook-cell:/Users/aaronwalker/Desktop/DataVisualization-Challenge/Pymaceuticals/pymaceuticals_solution.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> # Put treatments into a list for for loop (and later for plot labels)
# ----> <a href='vscode-notebook-cell:/Users/aaronwalker/Desktop/DataVisualization-Challenge/Pymaceuticals/pymaceuticals_solution.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> treatments = [Capomulin, Ceftamin, Infubinol, Ramicane]
#       <a href='vscode-notebook-cell:/Users/aaronwalker/Desktop/DataVisualization-Challenge/Pymaceuticals/pymaceuticals_solution.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> # Create empty list to fill with tumor vol data (for plotting)
# ...

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
fig1, ax1 = plt.subplots()
ax1.set_ylabel('Final Tumor Volume (mm3)')
ax1.boxplot(vol_data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/aaronwalker/Desktop/DataVisualization-Challenge/Pymaceuticals/pymaceuticals_solution.ipynb Cell 20 line 4
#       <a href='vscode-notebook-cell:/Users/aaronwalker/Desktop/DataVisualization-Challenge/Pymaceuticals/pymaceuticals_solution.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> fig1, ax1 = plt.subplots()
#       <a href='vscode-notebook-cell:/Users/aaronwalker/Desktop/DataVisualization-Challenge/Pymaceuticals/pymaceuticals_solution.ipynb#X25sZmlsZQ%3D%3D?line=2'>3</a> ax1.set_ylabel('Final Tumor Volume (mm3)')
# ----> <a href='vscode-notebook-cell:/Users/aaronwalker/Desktop/DataVisualization-Challenge/Pymaceuticals/pymaceuticals_solution.ipynb#X25sZmlsZQ%3D%3D?line=3'>4</a> ax1.boxplot(vol_data)
# ...

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

# %%
Value = "Capomulin"
Capomulin_df = treatment_df.loc[treatment_df['Drug Regimen'] == Value]
Capomulin_df
# Out:
#     Mouse ID  Age_months  Weight (g)  Timepoint  Tumor Volume (mm3)  \
# 63      i557           1          24         45           47.685963
# 131     r157          22          25         15           46.539206
#
#      Metastatic Sites Drug Regimen     Sex
# 63                  1    Capomulin  Female
# 131                 0    Capomulin    Male

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

Capomulin_df.plot('Weight (g)', 'Tumor Volume (mm3)', kind='scatter', figsize=(7,5))
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
# Out:
# Text(0, 0.5, 'Average Tumor Volume (mm3)')

# %% [markdown]
# ## Correlation and Regression

# %%
x_values = Capomulin_df['Weight (g)']
y_values = Capomulin_df['Tumor Volume (mm3)']

# %%
# Calculate the correlation coefficient and a linear regression model ``
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.annotate(line_eq,(10,5),fontsize=15,color="red")

plt.show()
